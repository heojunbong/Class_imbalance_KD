# %% [markdown]
# # 필요한 라이브러리 Import하기

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import optuna 
import lightgbm as lgb 
from sklearn.metrics import accuracy_score, roc_auc_score,precision_score, confusion_matrix,recall_score 
from sklearn.model_selection import cross_val_score, train_test_split
import os

# %%
# Train data Test data 로드해주기

train_data=pd.read_csv('/dshome/WoongLab/heo/construction_oil/preprocessed_data/breastcancer_train_data.csv')
test_data=pd.read_csv('/dshome/WoongLab/heo/construction_oil/preprocessed_data/breastcancer_test_data.csv')

# %%
train_stage_features=['A Stage','differentiate','Race','T Stage ','Grade','Estrogen Status','Progesterone Status','Marital Status','N Stage',
                      '6th Stage','Regional Node Examined','Tumor Size','Reginol Node Positive','Age','Survival Months']

# %%
train_X=train_data[train_stage_features]
train_y=train_data['Status']

new_test_data_X=test_data[train_stage_features]
new_test_data_y=test_data['Status']

# %%
train_y.value_counts()
# Out:
# 0    2726
# 1     493
# Name: Status, dtype: int64

# %%
train_X
# Out:
#       A Stage  differentiate  Race  T Stage   Grade  Estrogen Status  \
# 0           1              3     2         1      1                1
# 1           1              1     2         0      3                1
# 2           1              0     2         0      2                1
# 3           1              0     2         1      2                1
# 4           1              3     2         0      1                1
# ...       ...            ...   ...       ...    ...              ...
# 3214        0              1     2         1      3                1
# 3215        1              0     2         1      2                1
# 3216        1              3     2         1      1                1
# 3217        1              1     2         1      3                1
# 3218        1              1     0         1      3                0
#
#       Progesterone Status  Marital Status  N Stage  6th Stage  \
# 0                       1               1        0          1
# 1                       1               1        0          0
# 2                       1               1        0          0
# 3                       0               0        1          2
# 4                       1               1        0          0
# ...                   ...             ...      ...        ...
# 3214                    1               3        2          4
# 3215                    1               1        1          2
# 3216                    1               3        0          1
# 3217                    1               1        0          1
# 3218                    0               3        1          2
#
#       Regional Node Examined  Tumor Size  Reginol Node Positive  Age  \
# 0                         13          40                      1   50
# 1                         11          12                      2   59
# 2                          8          11                      2   44
# 3                         32          25                      5   59
# 4                          4          18                      1   69
# ...                      ...         ...                    ...  ...
# 3214                      18          35                     18   37
# 3215                      12          50                      7   47
# 3216                       2          32                      1   65
# 3217                      17          40                      1   53
# 3218                      13          30                      4   31
#
#       Survival Months
# 0                  50
# 1                  99
# 2                  77
# 3                 107
# 4                  48
# ...               ...
# 3214               77
# 3215               71
# 3216               80
# 3217                8
# 3218                5
#
# [3219 rows x 15 columns]

# %%
# class weight 적용하기 위해 y label의 비율을 구하기

ratio=train_y.value_counts()[0]/train_y.value_counts()[1]

# %% [markdown]
# ## 베이지안 최적화해주기 - LightgbmClassifier
#
# **1. 5-fold 교차검증 이용해서 Train data로 Validation set을 Auc가 최고였을 때의 하이퍼파라미터 구하기**
#
# **2. Learning rate 0.01~0.1, max_depth 3~9, n_estimators 100~1000이었을 때에서 가장 최적의 하이퍼파라미터 구하기**

# %%
def objective(trial):
    # Define hyperparameters to optimize 
    params={
        'boosting_type':'gbdt',
        'objective':'binary',
        'metric':'binary_logloss',
        'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
        'max_depth':trial.suggest_int('max_depth',3,9),
        'n_estimators':trial.suggest_int("n_estimators",100,1000)
    }
    # Train and evaluate model 
    lgb_cv=lgb.LGBMClassifier(**params, random_state=42,scale_pos_weight=ratio)
    scores=cross_val_score(lgb_cv,train_X,train_y,cv=5,scoring='roc_auc')
    auc=scores.mean()
    return auc 

# Define study object and optimize 

study=optuna.create_study(direction='maximize',study_name='lgb_boost_opt',load_if_exists=True)
study.optimize(objective, n_trials=50)

# Print best hyperparameters and auc
print(f'Best hyperparameters: {study.best_params}')
print(f'Best AUC: {study.best_value:.4f}')
# Out:
# [I 2023-04-15 01:36:18,487] A new study created in memory with name: lgb_boost_opt
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:36
. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:44,493] Trial 38 finished with value: 0.8563239516937327 and parameters: {'learning_rate': 0.02771284094314754, 'max_depth': 4, 'n_estimators': 361}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:45,835] Trial 39 finished with value: 0.8521373271925603 and parameters: {'learning_rate': 0.04139815678715504, 'max_depth': 4, 'n_estimators': 308}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:52,612] Trial 40 finished with value: 0.8272233901030006 and parameters: {'learning_rate': 0.032464560896302105, 'max_depth': 8, 'n_estimators': 714}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:53,158] Trial 41 finished with value: 0.8694394848738604 and parameters: {'learning_rate': 0.020727352967220315, 'max_depth': 3, 'n_estimators': 172}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:53,787] Trial 42 finished with value: 0.8706530910060211 and parameters: {'learning_rate': 0.024494654655121097, 'max_depth': 3, 'n_estimators': 204}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:54,503] Trial 43 finished with value: 0.8704763085216183 and parameters: {'learning_rate': 0.024279560825505284, 'max_depth': 3, 'n_estimators': 235}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:55,203] Trial 44 finished with value: 0.8704869077748688 and parameters: {'learning_rate': 0.024113934000529504, 'max_depth': 3, 'n_estimators': 230}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:56,400] Trial 45 finished with value: 0.8646572805587972 and parameters: {'learning_rate': 0.023059919465135758, 'max_depth': 3, 'n_estimators': 420}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:57,062] Trial 46 finished with value: 0.869553558114689 and parameters: {'learning_rate': 0.025788804792619986, 'max_depth': 4, 'n_estimators': 129}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:37:57,923] Trial 47 finished with value: 0.8695419662822772 and parameters: {'learning_rate': 0.0238678334393849, 'max_depth': 3, 'n_estimators': 290}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:38:02,929] Trial 48 finished with value: 0.8428259474823788 and parameters: {'learning_rate': 0.017962827777817273, 'max_depth': 8, 'n_estimators': 498}. Best is trial 21 with value: 0.8711446908788231.
# /tmp/ipykernel_166966/2141867322.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
# [I 2023-04-15 01:38:05,025] Trial 49 finished with value: 0.8578793845485476 and parameters: {'learning_rate': 0.015718692867369176, 'max_depth': 6, 'n_estimators': 228}. Best is trial 21 with value: 0.8711446908788231.
# Best hyperparameters: {'learning_rate': 0.025961944894828903, 'max_depth': 3, 'n_estimators': 202}
# Best AUC: 0.8711

# %%
# AUC값이 가장 높은 하이퍼파라미터로 파인튜닝해주기

lgb=lgb.LGBMClassifier(learning_rate=0.025961944894828903,max_depth=3,n_estimators=202,scale_pos_weight=ratio,random_state=42)

# %%
# 모델 학습시키기

lgb.fit(train_X,train_y)
# Out:
# LGBMClassifier(learning_rate=0.025961944894828903, max_depth=3,
#                n_estimators=202, random_state=42,
#                scale_pos_weight=5.529411764705882)

# %%
# AUC를 구하기 위해 클래스의 확률 값 구해주기

prob=lgb.predict_proba(new_test_data_X)[:,1]

# %%
# 모델 성능을 평가하기 위해 성능지표 함수 만들어주기

from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

def get_clf_prob(y_test, probability):
  pred=np.where(probability > 0.5,1,0)
  confusion=confusion_matrix(y_test, pred)
  accuracy=accuracy_score(y_test,pred)
  precision=precision_score(y_test,pred) 
  recall=recall_score(y_test,pred) 
  # F1 스코어 추가 
  f1=f1_score(y_test,pred,average='macro')
  Roc_score=roc_auc_score(y_test,probability)
  print('임계값: ', 0.5) 
  print('오차행렬')
  print(confusion) 
  # f1 score print 추가 
  print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4: .4f}'.format(accuracy,precision,recall,f1,Roc_score))

# %%
get_clf_prob(new_test_data_y,prob)
# Out:
# 임계값:  0.5
# 오차행렬
# [[596  86]
#  [ 39  84]]
# 정확도: 0.8447, 정밀도: 0.4941, 재현율: 0.6829, F1:0.7392, AUC: 0.8510
