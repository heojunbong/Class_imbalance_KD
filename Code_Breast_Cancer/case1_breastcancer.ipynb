# %% [markdown]
# # 필요한 라이브러리 Import하기

# %%
import pandas as pd 
import numpy as np 
import os 
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score,roc_auc_score,mean_squared_error
import warnings
warnings.filterwarnings(action='ignore')
import random
from lightgbm import LGBMClassifier
from lightgbm import LGBMRegressor

# %%
# train data와 test data 로드하기

train_data=pd.read_csv('/dshome/WoongLab/heo/construction_oil/preprocessed_data/breastcancer_train_data.csv')
test_data=pd.read_csv('/dshome/WoongLab/heo/construction_oil/preprocessed_data/breastcancer_test_data.csv')

# %%
train_stage_features=['A Stage','differentiate','Race','T Stage ','Grade','Estrogen Status','Progesterone Status','Marital Status','N Stage',
                      '6th Stage','Regional Node Examined','Tumor Size','Reginol Node Positive','Age','Survival Months']
test_stage_features=['A Stage','differentiate','Race','T Stage ','Grade','Estrogen Status','Progesterone Status','Marital Status','N Stage']

# %%
train_data
# Out:
#       Age  Race  Marital Status  T Stage   N Stage  6th Stage  differentiate  \
# 0      50     2               1         1        0          1              3
# 1      59     2               1         0        0          0              1
# 2      44     2               1         0        0          0              0
# 3      59     2               0         1        1          2              0
# 4      69     2               1         0        0          0              3
# ...   ...   ...             ...       ...      ...        ...            ...
# 3214   37     2               3         1        2          4              1
# 3215   47     2               1         1        1          2              0
# 3216   65     2               3         1        0          1              3
# 3217   53     2               1         1        0          1              1
# 3218   31     0               3         1        1          2              1
#
#       Grade  A Stage  Tumor Size  Estrogen Status  Progesterone Status  \
# 0         1        1          40                1                    1
# 1         3        1          12                1                    1
# 2         2        1          11                1                    1
# 3         2        1          25                1                    0
# 4         1        1          18                1                    1
# ...     ...      ...         ...              ...                  ...
# 3214      3        0          35                1                    1
# 3215      2        1          50                1                    1
# 3216      1        1          32                1                    1
# 3217      3        1          40                1                    1
# 3218      3        1          30                0                    0
#
#       Regional Node Examined  Reginol Node Positive  Survival Months  Status
# 0                         13                      1               50       0
# 1                         11                      2               99       0
# 2                          8                      2               77       0
# 3                         32                      5              107       0
# 4                          4                      1               48       0
# ...                      ...                    ...              ...     ...
# 3214                      18                     18               77       0
# 3215                      12                      7               71       0
# 3216                       2                      1               80       0
# 3217                      17                      1                8       0
# 3218                      13                      4                5       1
#
# [3219 rows x 16 columns]

# %%
## Train data와 Test data의 독립변수와 종속변수 설정하기

train_X=train_data.loc[:,train_stage_features]
train_y=train_data['Status']
new_test_data_X=test_data.loc[:,test_stage_features]
new_test_data_y=test_data['Status']

# %%
# 데이터셋에 Class weight해주기

ratio=train_y.value_counts()[0]/train_y.value_counts()[1]

# %%
# train에는 있는데 test data에는 없는 컬럼 찾기

train_data_columns=np.array(train_X.columns)
test_data_columns=np.array(new_test_data_X.columns)
np.setdiff1d(train_data_columns,test_data_columns)
# Out:
# array(['6th Stage', 'Age', 'Reginol Node Positive',
#        'Regional Node Examined', 'Survival Months', 'Tumor Size'],
#       dtype=object)

# %%
# !nvidia-smi
# Out:
# Thu Apr 20 02:23:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.54       Driver Version: 510.54       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:03:00.0 Off |                  N/A |
# |  0%   32C    P8    19W / 250W |   4461MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  On   | 00000000:04:00.0 Off |                  N/A |
# |  0%   31C    P8     9W / 250W |   8920MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  On   | 00000000:05:00.0 Off |                  N/A |
# |  0%   26C    P8     8W / 250W |   8920MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  On   | 00000000:81:00.0 Off |                  N/A |
# |  0%   24C    P8     8W / 250W |   8894MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    265501      C   /bin/python3                     4459MiB |
# |    1   N/A  N/A    264879      C   /bin/python3                     4459MiB |
# |    1   N/A  N/A    264958      C   /bin/python3                     4459MiB |
# |    2   N/A  N/A    264847      C   /bin/python3                     4459MiB |
# |    2   N/A  N/A    265181      C   /bin/python3                     4459MiB |
# |    3   N/A  N/A    264062      C   /bin/python3                     4433MiB |
# |    3   N/A  N/A    265381      C   /bin/python3                     4459MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Test data에 없는 변수들을 다 생성했으므로 LightgbmRegressor 분류모델을 만듬
#
# ### 베이지안 최적화해주기 - LightgbmRegressor
#
# **1. 5-fold 교차검증 이용해서 Train data로 Validation set을 RMSE가 최저였을 때의 하이퍼파라미터 구하기**
#
# **2. Learning rate 0.01~0.1, max_depth 3~9, n_estimators 100~1000이었을 때에서 가장 최적의 하이퍼파라미터 구하기**

# %%
# 변수 6th Stage을 예측하는 모형 만들어 주기

import optuna
from lightgbm import LGBMRegressor
from sklearn.model_selection import cross_val_score

test_data_columns=test_stage_features
y='6th Stage'

train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]



# Objective 함수 정의
def objective(trial):
    
    # 하이퍼파라미터 탐색할 공간 정의
    params = {
        'n_estimators': trial.suggest_int('n_estimators',100,1000),
        'max_depth': trial.suggest_int('max_depth',3,9),
        'learning_rate': trial.suggest_loguniform('learning_rate',0.01,0.1),
    }
    
    # LGBMRegressor 모델 객체 생성
    model = LGBMRegressor(**params, random_state=42)
    
    # 교차검증 수행하여 모델 성능 측정
    scores = -1 * cross_val_score(model, train_X_new, train_y_new,
                                  cv=5, scoring='neg_mean_squared_error')
    
    # 교차검증 평균 점수 리턴
    return np.mean(scores)


# Optuna study 생성
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)
# Out:
# [I 2023-04-19 11:56:06,806] A new study created in memory with name: no-name-211cac82-9240-4e49-85d5-baba6b80acec
# [I 2023-04-19 11:56:07,481] Trial 0 finished with value: 0.02628574546425592 and parameters: {'n_estimators': 146, 'max_depth': 7, 'learning_rate': 0.014758369041791227}. Best is trial 0 with value: 0.02628574546425592.
# [I 2023-04-19 11:56:07,741] Trial 1 finished with value: 0.16617253965600326 and parameters: {'n_estimators': 104, 'max_depth': 3, 'learning_rate': 0.011170298713559852}. Best is trial 0 with value: 0.02628574546425592.
# [I 2023-04-19 11:56:08,228] Trial 2 finished with value: 0.14306917353628962 and parameters: {'n_estimators': 119, 'max_depth': 9, 'learning_rate': 0.010247942306955948}. Best is trial 0 with value: 0.02628574546425592.
# [I 2023-04-19 11:56:10,692] Trial 3 finished with value: 1.2666212041729795e-05 and parameters: {'n_estimators': 840, 'max_depth': 4, 'learning_rate': 0.05629548246953177}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:16,280] Trial 4 finished with value: 3.251424219128102e-05 and parameters: {'n_estimators': 746, 'max_depth': 8, 'learning_rate': 0.09372259201579144}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:19,100] Trial 5 finished with value: 4.518600544614289e-05 and parameters: {'n_estimators': 562, 'max_depth': 6, 'learning_rate': 0.04284668529280235}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:21,068] Trial 6 finished with value: 0.0011937816547989003 and parameters: {'n_estimators': 396, 'max_depth': 9, 'learning_rate': 0.015243932712815994}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:25,009] Trial 7 finished with value: 4.645695530713936e-05 and parameters: {'n_estimators': 562, 'max_depth': 9, 'learning_rate': 0.043643115510501394}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:27,131] Trial 8 finished with value: 0.00041184744024367676 and parameters: {'n_estimators': 474, 'max_depth': 6, 'learning_rate': 0.018579058348143333}. Best is trial 3 with value: 1.2666212041729795e-05.
# [I 2023-04-19 11:56:28,148] Trial 9 finished with value: 0.004182016625596382 and parameters: {'n_estimators': 226, 'max_depth': 9, 'learning_rate': 0.014931735947474224}. Best is trial 3 with value: 1.2666212041729795e-05.
# {'n_estimators': 840, 'max_depth': 4, 'learning_rate': 0.05629548246953177}

# %%
# Print best hyperparameters and auc

print(f'Best hyperparameters: {study.best_params}')
print(f'Best RMSE: {study.best_value:.4f}')
# Out:
# Best hyperparameters: {'n_estimators': 840, 'max_depth': 4, 'learning_rate': 0.05629548246953177}
# Best RMSE: 0.0000

# %%
(est,depth,rate)=study.best_params.values()

# %%
# 앞서 구한 최적의 하이퍼파라미터로 튜닝해주고 튜닝된 모델로 Test data 새로운 컬럼 생성해주기

def bestreg_parametertuning(rate,depth,est,test_data_columns,y):
    best_lgbmreg=LGBMRegressor(learning_rate=rate,max_depth=depth,n_estimators=est,random_state=42)
    best_lgbmreg.fit(train_X[test_data_columns], train_X[y])
    new_test_data_X[y]=best_lgbmreg.predict(new_test_data_X[test_data_columns])

# %%
# Test datadp 6th Stage변수가 생성됨

bestreg_parametertuning(rate,depth,est,test_data_columns,'6th Stage')

# %%
new_test_data_X
# Out:
#      A Stage  differentiate  Race  T Stage   Grade  Estrogen Status  \
# 0        1.0              3     2         1      1                1
# 1        1.0              0     2         2      2                1
# 2        1.0              0     2         1      2                1
# 3        1.0              1     2         1      3                1
# 4        1.0              0     2         1      2                1
# ..       ...            ...   ...       ...    ...              ...
# 800      1.0              1     2         1      3                1
# 801      1.0              0     2         2      2                1
# 802      1.0              0     2         0      2                1
# 803      1.0              3     2         0      1                1
# 804      1.0              1     2         2      3                1
#
#      Progesterone Status  Marital Status  N Stage     6th Stage
# 0                      1               1        1  2.000000e+00
# 1                      0               1        0  2.000000e+00
# 2                      1               1        1  2.000000e+00
# 3                      1               1        0  1.000000e+00
# 4                      1               0        0  1.000000e+00
# ..                   ...             ...      ...           ...
# 800                    1               1        0  1.000000e+00
# 801                    1               1        2  4.000000e+00
# 802                    1               0        0  9.564947e-22
# 803                    1               1        0  9.564947e-22
# 804                    0               1        1  2.000000e+00
#
# [805 rows x 10 columns]

# %%
y='Regional Node Examined'
train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)

(est,depth,rate)=study.best_params.values()
print(rate,depth,est)
# Out:
# [I 2023-04-19 11:57:39,022] A new study created in memory with name: no-name-f682a12e-4131-4168-aedd-dd262723db20
# [I 2023-04-19 11:57:44,503] Trial 0 finished with value: 61.01877162972247 and parameters: {'n_estimators': 657, 'max_depth': 8, 'learning_rate': 0.02378497109191181}. Best is trial 0 with value: 61.01877162972247.
# [I 2023-04-19 11:57:47,629] Trial 1 finished with value: 60.25558668587422 and parameters: {'n_estimators': 967, 'max_depth': 4, 'learning_rate': 0.02776444166192067}. Best is trial 1 with value: 60.25558668587422.
# [I 2023-04-19 11:57:51,987] Trial 2 finished with value: 60.833914172235175 and parameters: {'n_estimators': 523, 'max_depth': 8, 'learning_rate': 0.02439980814770578}. Best is trial 1 with value: 60.25558668587422.
# [I 2023-04-19 11:57:53,682] Trial 3 finished with value: 60.1807518296619 and parameters: {'n_estimators': 195, 'max_depth': 8, 'learning_rate': 0.03462137707459102}. Best is trial 3 with value: 60.1807518296619.
# [I 2023-04-19 11:57:59,346] Trial 4 finished with value: 62.45546177758558 and parameters: {'n_estimators': 829, 'max_depth': 7, 'learning_rate': 0.0652806135855248}. Best is trial 3 with value: 60.1807518296619.
# [I 2023-04-19 11:58:00,137] Trial 5 finished with value: 59.244959530293706 and parameters: {'n_estimators': 356, 'max_depth': 3, 'learning_rate': 0.042832455773943554}. Best is trial 5 with value: 59.244959530293706.
# [I 2023-04-19 11:58:05,555] Trial 6 finished with value: 62.06708980525404 and parameters: {'n_estimators': 622, 'max_depth': 9, 'learning_rate': 0.05130755465641605}. Best is trial 5 with value: 59.244959530293706.
# [I 2023-04-19 11:58:07,959] Trial 7 finished with value: 61.3930491965437 and parameters: {'n_estimators': 572, 'max_depth': 5, 'learning_rate': 0.0762598578641189}. Best is trial 5 with value: 59.244959530293706.
# [I 2023-04-19 11:58:11,167] Trial 8 finished with value: 61.435323744025766 and parameters: {'n_estimators': 725, 'max_depth': 5, 'learning_rate': 0.056062325158364276}. Best is trial 5 with value: 59.244959530293706.
# [I 2023-04-19 11:58:15,047] Trial 9 finished with value: 62.321695784086316 and parameters: {'n_estimators': 935, 'max_depth': 5, 'learning_rate': 0.09748437874476469}. Best is trial 5 with value: 59.244959530293706.
# {'n_estimators': 356, 'max_depth': 3, 'learning_rate': 0.042832455773943554}
# 0.042832455773943554 3 356

# %%
# Test datadp Regional Node Examined변수가 생성됨

bestreg_parametertuning(rate,depth,est,test_data_columns,'Regional Node Examined')

# %%
new_test_data_X
# Out:
#      A Stage  differentiate  Race  T Stage   Grade  Estrogen Status  \
# 0        1.0              3     2         1      1                1
# 1        1.0              0     2         2      2                1
# 2        1.0              0     2         1      2                1
# 3        1.0              1     2         1      3                1
# 4        1.0              0     2         1      2                1
# ..       ...            ...   ...       ...    ...              ...
# 800      1.0              1     2         1      3                1
# 801      1.0              0     2         2      2                1
# 802      1.0              0     2         0      2                1
# 803      1.0              3     2         0      1                1
# 804      1.0              1     2         2      3                1
#
#      Progesterone Status  Marital Status  N Stage     6th Stage  \
# 0                      1               1        1  2.000000e+00
# 1                      0               1        0  2.000000e+00
# 2                      1               1        1  2.000000e+00
# 3                      1               1        0  1.000000e+00
# 4                      1               0        0  1.000000e+00
# ..                   ...             ...      ...           ...
# 800                    1               1        0  1.000000e+00
# 801                    1               1        2  4.000000e+00
# 802                    1               0        0  9.564947e-22
# 803                    1               1        0  9.564947e-22
# 804                    0               1        1  2.000000e+00
#
#      Regional Node Examined
# 0                 14.533824
# 1                 14.045237
# 2                 15.797581
# 3                 13.801471
# 4                 13.904897
# ..                      ...
# 800               13.801471
# 801               21.155025
# 802               12.308367
# 803               11.892922
# 804               15.616954
#
# [805 rows x 11 columns]

# %%
y='Tumor Size'
train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)

(est,depth,rate)=study.best_params.values()
print(rate,depth,est)
# Out:
# [I 2023-04-19 11:59:50,198] A new study created in memory with name: no-name-3449a597-a05a-4d5e-bba0-48a451694f2d
# [I 2023-04-19 11:59:56,790] Trial 0 finished with value: 117.21850421954169 and parameters: {'n_estimators': 680, 'max_depth': 8, 'learning_rate': 0.017771989808855276}. Best is trial 0 with value: 117.21850421954169.
# [I 2023-04-19 12:00:02,943] Trial 1 finished with value: 122.42685274971923 and parameters: {'n_estimators': 802, 'max_depth': 5, 'learning_rate': 0.052141526342352904}. Best is trial 0 with value: 117.21850421954169.
# [I 2023-04-19 12:00:06,091] Trial 2 finished with value: 124.47419432690644 and parameters: {'n_estimators': 564, 'max_depth': 6, 'learning_rate': 0.07255297888176565}. Best is trial 0 with value: 117.21850421954169.
# [I 2023-04-19 12:00:08,197] Trial 3 finished with value: 116.17017295712303 and parameters: {'n_estimators': 250, 'max_depth': 8, 'learning_rate': 0.040491622917486175}. Best is trial 3 with value: 116.17017295712303.
# [I 2023-04-19 12:00:08,602] Trial 4 finished with value: 112.40566164860977 and parameters: {'n_estimators': 174, 'max_depth': 3, 'learning_rate': 0.07004910206390128}. Best is trial 4 with value: 112.40566164860977.
# [I 2023-04-19 12:00:11,010] Trial 5 finished with value: 119.11550929792206 and parameters: {'n_estimators': 822, 'max_depth': 4, 'learning_rate': 0.04612079719159676}. Best is trial 4 with value: 112.40566164860977.
# [I 2023-04-19 12:00:11,824] Trial 6 finished with value: 109.36266325360259 and parameters: {'n_estimators': 354, 'max_depth': 3, 'learning_rate': 0.017605136710540148}. Best is trial 6 with value: 109.36266325360259.
# [I 2023-04-19 12:00:15,929] Trial 7 finished with value: 117.95451270747738 and parameters: {'n_estimators': 570, 'max_depth': 7, 'learning_rate': 0.02679229152899786}. Best is trial 6 with value: 109.36266325360259.
# [I 2023-04-19 12:00:16,608] Trial 8 finished with value: 110.5025737732594 and parameters: {'n_estimators': 182, 'max_depth': 4, 'learning_rate': 0.03153632650540766}. Best is trial 6 with value: 109.36266325360259.
# [I 2023-04-19 12:00:18,550] Trial 9 finished with value: 115.07734257800621 and parameters: {'n_estimators': 881, 'max_depth': 3, 'learning_rate': 0.026973479672790807}. Best is trial 6 with value: 109.36266325360259.
# {'n_estimators': 354, 'max_depth': 3, 'learning_rate': 0.017605136710540148}
# 0.017605136710540148 3 354

# %%
# Test data에 Tumor Size변수가 생성됨

bestreg_parametertuning(rate,depth,est,test_data_columns,'Tumor Size')

# %%
y='Reginol Node Positive'
train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)

(est,depth,rate)=study.best_params.values()
print(rate,depth,est)
bestreg_parametertuning(rate,depth,est,test_data_columns,'Reginol Node Positive')
# Out:
# [I 2023-04-19 12:01:06,557] A new study created in memory with name: no-name-1cd12220-e1b9-4b41-9fe9-954f37cf0ed5
# [I 2023-04-19 12:01:06,983] Trial 0 finished with value: 6.888255352594358 and parameters: {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.0199118518865309}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:12,210] Trial 1 finished with value: 7.262379874567342 and parameters: {'n_estimators': 847, 'max_depth': 6, 'learning_rate': 0.010332014084841329}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:13,918] Trial 2 finished with value: 7.041633826416413 and parameters: {'n_estimators': 233, 'max_depth': 6, 'learning_rate': 0.014108701181263629}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:18,381] Trial 3 finished with value: 7.370478527661172 and parameters: {'n_estimators': 746, 'max_depth': 6, 'learning_rate': 0.016829577527647896}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:23,742] Trial 4 finished with value: 7.6035027081726625 and parameters: {'n_estimators': 612, 'max_depth': 9, 'learning_rate': 0.031729498461415026}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:24,766] Trial 5 finished with value: 7.129694584578677 and parameters: {'n_estimators': 473, 'max_depth': 3, 'learning_rate': 0.02566678313081671}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:31,771] Trial 6 finished with value: 8.062874039825495 and parameters: {'n_estimators': 862, 'max_depth': 8, 'learning_rate': 0.07442080219933699}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:32,367] Trial 7 finished with value: 7.098512782236595 and parameters: {'n_estimators': 174, 'max_depth': 4, 'learning_rate': 0.045584956173153245}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:33,317] Trial 8 finished with value: 7.263407770070053 and parameters: {'n_estimators': 450, 'max_depth': 3, 'learning_rate': 0.04902702837930465}. Best is trial 0 with value: 6.888255352594358.
# [I 2023-04-19 12:01:35,174] Trial 9 finished with value: 7.114612818283473 and parameters: {'n_estimators': 206, 'max_depth': 8, 'learning_rate': 0.019798469065739434}. Best is trial 0 with value: 6.888255352594358.
# {'n_estimators': 154, 'max_depth': 3, 'learning_rate': 0.0199118518865309}
# 0.0199118518865309 3 154

# %%
y='Age'
train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)

(est,depth,rate)=study.best_params.values()
print(rate,depth,est)

# Test data에 Age변수가 생성됨
bestreg_parametertuning(rate,depth,est,test_data_columns,'Age')
# Out:
# [I 2023-04-19 12:01:54,371] A new study created in memory with name: no-name-936e9cb2-3932-4b8f-ab12-a0b6f30eadfc
# [I 2023-04-19 12:01:56,491] Trial 0 finished with value: 76.58995845939155 and parameters: {'n_estimators': 998, 'max_depth': 3, 'learning_rate': 0.05459095842001616}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:01,720] Trial 1 finished with value: 77.08571398763948 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.011396528543836132}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:07,817] Trial 2 finished with value: 80.07636517139558 and parameters: {'n_estimators': 885, 'max_depth': 7, 'learning_rate': 0.07236310580732813}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:10,040] Trial 3 finished with value: 76.60978061077479 and parameters: {'n_estimators': 244, 'max_depth': 9, 'learning_rate': 0.02122095906130223}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:14,864] Trial 4 finished with value: 78.76592009464164 and parameters: {'n_estimators': 880, 'max_depth': 6, 'learning_rate': 0.057685338325891775}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:16,444] Trial 5 finished with value: 77.91699095347994 and parameters: {'n_estimators': 280, 'max_depth': 6, 'learning_rate': 0.09117754144939168}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:18,928] Trial 6 finished with value: 77.36782175963124 and parameters: {'n_estimators': 846, 'max_depth': 4, 'learning_rate': 0.0646232850103433}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:21,346] Trial 7 finished with value: 77.75693283799315 and parameters: {'n_estimators': 344, 'max_depth': 7, 'learning_rate': 0.04751726893136599}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:23,814] Trial 8 finished with value: 77.55883065655928 and parameters: {'n_estimators': 853, 'max_depth': 4, 'learning_rate': 0.061587816178000736}. Best is trial 0 with value: 76.58995845939155.
# [I 2023-04-19 12:02:26,141] Trial 9 finished with value: 77.8209153805615 and parameters: {'n_estimators': 430, 'max_depth': 6, 'learning_rate': 0.05262381266199041}. Best is trial 0 with value: 76.58995845939155.
# {'n_estimators': 998, 'max_depth': 3, 'learning_rate': 0.05459095842001616}
# 0.05459095842001616 3 998

# %%
y='Survival Months'
train_X_new=train_X.loc[:,test_data_columns]
train_y_new=train_X.loc[:,y]
study = optuna.create_study(direction='minimize')

# study 실행 (n_trials는 시도 횟수)
study.optimize(objective, n_trials=10)

# 최적화된 하이퍼파라미터 값 출력
print(study.best_params)

(est,depth,rate)=study.best_params.values()
print(rate,depth,est)

# Test data에 Survival Months변수가 생성됨
bestreg_parametertuning(rate,depth,est,test_data_columns,'Survival Months')
# Out:
# [I 2023-04-19 12:03:18,324] A new study created in memory with name: no-name-e6de2306-db3a-4614-85ca-95bb124a5e5c
# [I 2023-04-19 12:03:18,694] Trial 0 finished with value: 507.82860753672037 and parameters: {'n_estimators': 137, 'max_depth': 3, 'learning_rate': 0.07448914467782536}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:19,344] Trial 1 finished with value: 514.3445271501251 and parameters: {'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.05821301525698846}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:20,662] Trial 2 finished with value: 529.0097166889229 and parameters: {'n_estimators': 185, 'max_depth': 7, 'learning_rate': 0.08595641389767766}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:23,817] Trial 3 finished with value: 519.09116211868 and parameters: {'n_estimators': 687, 'max_depth': 5, 'learning_rate': 0.02293877777028639}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:25,693] Trial 4 finished with value: 510.42346615433536 and parameters: {'n_estimators': 575, 'max_depth': 3, 'learning_rate': 0.02643548320040537}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:27,013] Trial 5 finished with value: 510.7078702774312 and parameters: {'n_estimators': 401, 'max_depth': 4, 'learning_rate': 0.018385073249526745}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:30,112] Trial 6 finished with value: 533.1300318067257 and parameters: {'n_estimators': 356, 'max_depth': 9, 'learning_rate': 0.04535763359929036}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:36,575] Trial 7 finished with value: 557.7304327338328 and parameters: {'n_estimators': 910, 'max_depth': 7, 'learning_rate': 0.0669098433061844}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:38,728] Trial 8 finished with value: 526.7034261347231 and parameters: {'n_estimators': 365, 'max_depth': 6, 'learning_rate': 0.04973273484246792}. Best is trial 0 with value: 507.82860753672037.
# [I 2023-04-19 12:03:47,394] Trial 9 finished with value: 545.0627479227036 and parameters: {'n_estimators': 994, 'max_depth': 9, 'learning_rate': 0.02948700478993314}. Best is trial 0 with value: 507.82860753672037.
# {'n_estimators': 137, 'max_depth': 3, 'learning_rate': 0.07448914467782536}
# 0.07448914467782536 3 137

# %%
newtestdata=pd.concat([new_test_data_X,new_test_data_y],axis=1)

# %%
newtestdata.head(5)
# Out:
#    A Stage  differentiate  Race  T Stage   Grade  Estrogen Status  \
# 0      1.0              3     2         1      1                1
# 1      1.0              0     2         2      2                1
# 2      1.0              0     2         1      2                1
# 3      1.0              1     2         1      3                1
# 4      1.0              0     2         1      2                1
#
#    Progesterone Status  Marital Status  N Stage  6th Stage  \
# 0                    1               1        1        2.0
# 1                    0               1        0        2.0
# 2                    1               1        1        2.0
# 3                    1               1        0        1.0
# 4                    1               0        0        1.0
#
#    Regional Node Examined  Tumor Size  Reginol Node Positive        Age  \
# 0               14.533824   31.807107               5.759757  56.493414
# 1               14.045237   69.495095               2.116119  58.317502
# 2               15.797581   32.202540               5.759757  54.145202
# 3               13.801471   30.432246               1.935915  51.412252
# 4               13.904897   30.557379               1.935915  55.138632
#
#    Survival Months  Status
# 0        73.060825       0
# 1        71.502406       1
# 2        72.067159       0
# 3        72.784810       0
# 4        70.362350       0

# %% [markdown]
# ## Test data에 없는 변수들을 다 생성했으므로 LightgbmClassifier 분류모델을 만듬
#
# ### 베이지안 최적화해주기 - LightgbmClassifier
#
# **1. 5-fold 교차검증 이용해서 Train data로 Validation set을 Auc가 최고였을 때의 하이퍼파라미터 구하기**
#
# **2. Learning rate 0.01~0.1, max_depth 3~9, n_estimators 100~1000이었을 때에서 가장 최적의 하이퍼파라미터 구하기**

# %%
import lightgbm as lgb

# %%
def objective(trial):
    # Define hyperparameters to optimize 
    params={
        'boosting_type':'gbdt',
        'objective':'binary',
        'metric':'binary_logloss',
        'learning_rate':trial.suggest_loguniform('learning_rate',0.01,0.1),
        'max_depth':trial.suggest_int('max_depth',3,9),
        'n_estimators':trial.suggest_int("n_estimators",100,1000)
    }
    # Train and evaluate model 
    lgb_cv=lgb.LGBMClassifier(**params, random_state=42,scale_pos_weight=ratio)
    scores=cross_val_score(lgb_cv,train_X,train_y,cv=5,scoring='roc_auc')
    auc=scores.mean()
    return auc 

# Define study object and optimize 

study=optuna.create_study(direction='maximize',study_name='lgb_boost_opt',load_if_exists=True)
study.optimize(objective, n_trials=10)

# Print best hyperparameters and auc
print(f'Best hyperparameters: {study.best_params}')
print(f'Best AUC: {study.best_value:.4f}')
# Out:
# [I 2023-04-19 12:07:09,157] A new study created in memory with name: lgb_boost_opt
# [I 2023-04-19 12:07:12,323] Trial 0 finished with value: 0.8518179421942762 and parameters: {'learning_rate': 0.01724627184448636, 'max_depth': 8, 'n_estimators': 304}. Best is trial 0 with value: 0.8518179421942762.
# [I 2023-04-19 12:07:14,215] Trial 1 finished with value: 0.8594611452746632 and parameters: {'learning_rate': 0.02039221329330299, 'max_depth': 4, 'n_estimators': 417}. Best is trial 1 with value: 0.8594611452746632.
# [I 2023-04-19 12:07:16,423] Trial 2 finished with value: 0.8412525812825382 and parameters: {'learning_rate': 0.036641091052061175, 'max_depth': 5, 'n_estimators': 389}. Best is trial 1 with value: 0.8594611452746632.
# [I 2023-04-19 12:07:20,523] Trial 3 finished with value: 0.8154941941704721 and parameters: {'learning_rate': 0.09660192292644951, 'max_depth': 5, 'n_estimators': 745}. Best is trial 1 with value: 0.8594611452746632.
# [I 2023-04-19 12:07:28,857] Trial 4 finished with value: 0.840697387864585 and parameters: {'learning_rate': 0.011198829328283155, 'max_depth': 8, 'n_estimators': 866}. Best is trial 1 with value: 0.8594611452746632.
# [I 2023-04-19 12:07:30,082] Trial 5 finished with value: 0.8703861429090786 and parameters: {'learning_rate': 0.01008374988342057, 'max_depth': 3, 'n_estimators': 407}. Best is trial 5 with value: 0.8703861429090786.
# [I 2023-04-19 12:07:30,917] Trial 6 finished with value: 0.8611760373434217 and parameters: {'learning_rate': 0.03905716954365209, 'max_depth': 3, 'n_estimators': 291}. Best is trial 5 with value: 0.8703861429090786.
# [I 2023-04-19 12:07:31,530] Trial 7 finished with value: 0.8588913059105907 and parameters: {'learning_rate': 0.06012133167986776, 'max_depth': 4, 'n_estimators': 139}. Best is trial 5 with value: 0.8703861429090786.
# [I 2023-04-19 12:07:33,352] Trial 8 finished with value: 0.829181817371295 and parameters: {'learning_rate': 0.09965477802011745, 'max_depth': 5, 'n_estimators': 319}. Best is trial 5 with value: 0.8703861429090786.
# [I 2023-04-19 12:07:41,437] Trial 9 finished with value: 0.8174074927548061 and parameters: {'learning_rate': 0.046966945782938224, 'max_depth': 8, 'n_estimators': 877}. Best is trial 5 with value: 0.8703861429090786.
# Best hyperparameters: {'learning_rate': 0.01008374988342057, 'max_depth': 3, 'n_estimators': 407}
# Best AUC: 0.8704

# %%
lgb=lgb.LGBMClassifier(learning_rate=  0.01008374988342057,max_depth= 3,n_estimators=407,scale_pos_weight=ratio,random_state=42)

# %%
# 모델 학습함

lgb.fit(train_X,train_y)
# Out:
# LGBMClassifier(learning_rate=0.01008374988342057, max_depth=3, n_estimators=407,
#                random_state=42, scale_pos_weight=5.529411764705882)

# %%
# AUC를 구하기 위해 예측된 클래스의 확률값을 구해주기

pred=lgb.predict_proba(new_test_data_X)[:,1]

# %%
# 모델 성능을 평가할 수 있는 함수 만들어주기

from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

def get_clf_prob(y_test, probability):
  pred=np.where(probability > 0.50,1,0)
  confusion=confusion_matrix(y_test, pred)
  accuracy=accuracy_score(y_test,pred)
  precision=precision_score(y_test,pred) 
  recall=recall_score(y_test,pred) 
  # F1 스코어 추가 
  f1=f1_score(y_test,pred,average='macro')
  Roc_score=roc_auc_score(y_test,probability)
  print('임계값: ', 0.5) 
  print('오차행렬')
  print(confusion) 
  # f1 score print 추가 
  print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4: .4f}'.format(accuracy,precision,recall,f1,Roc_score))

# %%
get_clf_prob(new_test_data_y,pred)
# Out:
# 임계값:  0.5
# 오차행렬
# [[615  67]
#  [ 80  43]]
# 정확도: 0.8174, 정밀도: 0.3909, 재현율: 0.3496, F1:0.6312, AUC: 0.6890
